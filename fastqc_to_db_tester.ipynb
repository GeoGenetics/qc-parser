# %%
import importlib
from parsers import fastqc_to_db_claude
import psycopg2

# %%
importlib.reload(fastqc_to_db_claude)
# Out:
# <module 'parsers.fastqc_to_db_claude' from '/home/glj523/GitHubRepoes/qc-parser/parsers/fastqc_to_db_claude.py'>

# %%
path = "/datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/"
conn = psycopg2.connect(
        host='dandypdb01fl', port=5432,
        dbname='smdb', user='postgres', password='Wtcantfw36c!91193', options="-c search_path=qc"
    )
res = fastqc_to_db_claude.mother(conn, path)
# Out:
# 2026-05-01 13:20:30,979 [INFO] Found 60 FastQC file(s) under /datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/
# 2026-05-01 13:20:30,981 [INFO] Processing FastQC: /datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/stats/reads/fastqc/raw/Lib_LV7008891944_L005_R2_fastqc.zip
# 2026-05-01 13:20:31,964 [INFO] Loaded as file_id=1
# 2026-05-01 13:20:31,966 [INFO] Processing FastQC: /datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/stats/reads/fastqc/raw/Lib_LV7008891944_L006_R2_fastqc.zip
# 2026-05-01 13:20:32,877 [INFO] Loaded as file_id=2
# 2026-05-01 13:20:32,878 [INFO] Processing FastQC: /datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/stats/reads/fastqc/raw/Lib_LV7008891944_L002_R2_fastqc.zip
# ...
