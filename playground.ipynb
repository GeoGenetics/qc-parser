# %%
len('/datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b')
# Out:
# 120

# %%
38.56836717921564 == 38.56836717921564
# Out:
# True

# %%
from psycopg2.extras import Decimal
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from psycopg2.extras import Decimal
#
# ImportError: cannot import name 'Decimal' from 'psycopg2.extras' (/home/glj523/miniconda3/lib/python3.13/site-packages/psycopg2/extras.py)

# %%
from decimal import Decimal

Decimal('38.56836717921564') == 38.56836717921564
# False
38.461703292989135
38.461703292989135
38.461703292989135
38.461703292989135
38.461703292989135
# Out:
# 38.461703292989135

# %%
Decimal('38.56836717921564') == 38.56836717921564
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Decimal('38.56836717921564') == 38.56836717921564
#
# NameError: name 'Decimal' is not defined
